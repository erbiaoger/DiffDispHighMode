# %%
# Mask-based Curve Detection Model - PyTorch Implementation
# Updated by ChatGPT - May 2025

import os
import json
import torch
import numpy as np
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from pathlib import Path

# =========================
# 1. Dataset
# =========================

from PIL import Image

class MaskDataset(Dataset):
    def __init__(self, root_dir, max_lines=3, img_size=(128, 512)):
        """
        root_dir: 数据集根目录，包含'data'和'labels'两个子文件夹
        max_lines: 每个样本最多的标签类别数
        img_size: 图像尺寸，默认(512, 128)
        """
        self.data_dir = os.path.join(root_dir, "data")
        self.labels_dir = os.path.join(root_dir, "labels")
        self.max_lines = max_lines
        self.img_size = img_size

        # 获取所有data图片的文件名（不带扩展名）
        self.sample_names = [
            os.path.splitext(f)[0]
            for f in os.listdir(self.data_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
        ]
        self.sample_names.sort()

    def __len__(self):
        return len(self.sample_names)

    def __getitem__(self, idx):
        # 读取data图片
        base_name = self.sample_names[idx]
        data_path = os.path.join(self.data_dir,  base_name + ".png")
        data_img = Image.open(data_path).convert("F").resize(self.img_size, resample=Image.BILINEAR)
        matrix = np.array(data_img, dtype=np.float32)  # [H, W]

        if np.max(matrix) > 0:
            matrix = matrix / np.max(matrix)
        matrix = torch.tensor(matrix).unsqueeze(0)  # [1, H, W]
        # 读取对应的label图片
        masks, types = [], []
        for i in range(1, self.max_lines+1):
            label_name = f"{base_name}_{i:02d}.png"
            label_path = os.path.join(self.labels_dir, label_name)
            if os.path.exists(label_path):
                label_img = Image.open(label_path).convert("L").resize(self.img_size, resample=Image.NEAREST)
                mask_array = np.array(label_img, dtype=np.uint8)  # [H, W]

                if np.max(mask_array) > 0:
                    mask_array = mask_array / np.max(mask_array)
                masks.append(mask_array)
                types.append(i)  # 假设类别就是1,2,3...，如有实际类别映射可自定义
            else:
                # 不足max_lines时补零
                masks.append(np.zeros_like(mask_array, dtype=np.uint8))
                types.append(0)

        masks = np.stack(masks[:self.max_lines])  # [max_lines, H, W]
        types = np.array(types[:self.max_lines])  # [max_lines]

        return matrix, torch.tensor(masks, dtype=torch.float32), torch.tensor(types, dtype=torch.long)

# %%
class MaskTypeTransformer(nn.Module):
    def __init__(self, in_channels=1, max_lines=3, embed_dim=256):
        super().__init__()
        num_types = max_lines + 1
        self.num_types = num_types
        self.max_lines= max_lines

        # CNN feature extractor
        self.backbone = nn.Sequential(
            nn.Conv2d(in_channels, 32, 3, padding=1),  # [B, 1, 128, 128] -> [B, 32, 128, 128]
            nn.ReLU(),
            nn.MaxPool2d(2),  # [B, 32, 64, 64]
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),  # [B, 64, 32, 32]
            nn.Conv2d(64, embed_dim, 3, padding=1),
            nn.ReLU(),        # [B, 256, 32, 32]
        )

        # Transformer encoder over flattened spatial features
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=8,batch_first=True)  # ✅ 添加这个参数
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)

        # Mask head - Upsample to (512, 128)
        self.mask_head = nn.Sequential(
            nn.ConvTranspose2d(embed_dim, 128, kernel_size=2, stride=2),  # 32x32 -> 64x64
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2),         # 64x64 -> 128x128
            nn.ReLU(),
            nn.ConvTranspose2d(64, max_lines, kernel_size=2, stride=2),   # 128x128 -> 256x256
            nn.ReLU(),
            nn.Conv2d(max_lines, max_lines, kernel_size=3, padding=1),
            nn.Upsample(size=(512, 128), mode="bilinear", align_corners=False)  # 输出尺寸统一
        )

        # Type head - predict [max_lines, num_types]
        self.type_head = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),  # [B, C, 1, 1] -> [B, C]
            nn.Linear(embed_dim, max_lines * num_types)
        )

    def forward(self, x):
        feats = self.backbone(x)  # [B, 256, 32, 32]
        B, C, H, W = feats.shape
        flattened = feats.view(B, C, -1).permute(2, 0, 1)  # [HW, B, C]
        encoded = self.transformer(flattened).permute(1, 2, 0).view(B, C, H, W)

        masks = self.mask_head(encoded)  # [B, max_lines, 512, 128]

        types = self.type_head(encoded)  # [B, max_lines * num_types]
        types = types.view(B, self.max_lines, self.num_types)  # [B, max_lines, num_types]
        return masks, types

# %%
# =========================
# 3. Loss Function
# =========================

def mask_loss(pred_masks, pred_types, gt_masks, gt_types):
    bce = nn.BCEWithLogitsLoss()
    ce = nn.CrossEntropyLoss(ignore_index=-1)

    mask_loss_val = bce(pred_masks, gt_masks)

    # Reshape pred_types: [B, max_lines, num_types] -> [B*max_lines, num_types]
    # gt_types: [B, max_lines] -> [B*max_lines]
    B, N, C = pred_types.shape
    pred_types = pred_types.view(B * N, C)
    gt_types = gt_types.view(B * N)
    type_loss_val = ce(pred_types, gt_types)

    return mask_loss_val + type_loss_val


# =========================
# 4. Training Loop
# =========================

def train(model, loader, optimizer, device):
    model.train()
    total_loss = 0
    for x, y_masks, y_types in loader:
        x = x.to(device)
        y_masks = y_masks.to(device)
        y_types = y_types.to(device)

        pred_masks, pred_types = model(x)
        loss = mask_loss(pred_masks, pred_types, y_masks, y_types)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    return total_loss / len(loader)

# %%
# =========================
# 5. Visualization
# =========================

def visualize_masks(matrix, pred_masks, threshold=0.5):
    fig, ax = plt.subplots(1, 1, figsize=(8, 4))
    ax.imshow(matrix.squeeze().cpu(), cmap='gray', aspect='auto')
    pred_masks = torch.sigmoid(pred_masks)
    for i in range(pred_masks.shape[0]):
        mask = pred_masks[i] > threshold
        if mask.sum() > 0:
            ax.contour(mask.cpu().numpy(), levels=[0.5], colors=[f"C{i}"])
    ax.set_title("Predicted Masks")
    plt.show()

# %%
# =========================
# 6. Run Example
# =========================

max_lines = 3

data_dir = "/csim2/zhangzhiyu/MyProjects/DiffDispHighMode/Dispersion/dataset_png/train"
dataset = MaskDataset(data_dir, max_lines=max_lines)
loader = DataLoader(dataset, batch_size=16, shuffle=True)

model = MaskTypeTransformer(max_lines=max_lines).cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

model_path = 'checkpoints/png4/model_lasted.pth'
model.load_state_dict(torch.load(model_path, weights_only=True))
optimizer_path = 'checkpoints/png4/optimizer_lasted.pth'
optimizer.load_state_dict(torch.load(optimizer_path, weights_only=True))

history_loss = []
for epoch in range(100, 500):
    loss = train(model, loader, optimizer, device="cuda")
    if epoch % 1 == 0:
        print(f"Epoch {epoch}: Loss = {loss:.4f}")
        history_loss.append([epoch, loss])
    if epoch % 20 == 0:
        # 保存模型权重和优化器状态，便于后续加载和复现实验
        save_dir = "checkpoints/png4"
        os.makedirs(save_dir, exist_ok=True)
        model_path = os.path.join(save_dir, f"model_{epoch:05d}.pth")
        optimizer_path = os.path.join(save_dir, f"optimizer_{epoch:05d}.pth")
        torch.save(model.state_dict(), model_path)
        torch.save(optimizer.state_dict(), optimizer_path)

history_loss = np.array(history_loss)

# 保存模型权重和优化器状态，便于后续加载和复现实验
save_dir = "checkpoints/png4"
os.makedirs(save_dir, exist_ok=True)
model_path = os.path.join(save_dir, "model_lasted.pth")
optimizer_path = os.path.join(save_dir, f"optimizer_lasted.pth")
torch.save(model.state_dict(), model_path)
torch.save(optimizer.state_dict(), optimizer_path)
# Out:
# Epoch 100: Loss = 0.0156
# Epoch 101: Loss = 0.0158
# Epoch 102: Loss = 0.0154
# Epoch 103: Loss = 0.0158
# Epoch 104: Loss = 0.0151
# Epoch 105: Loss = 0.0151
# Epoch 106: Loss = 0.0150
# Epoch 107: Loss = 0.0147
# Epoch 108: Loss = 0.0147
# Epoch 109: Loss = 0.0146
# Epoch 110: Loss = 0.0145
# Epoch 111: Loss = 0.0144
# Epoch 112: Loss = 0.0143
# Epoch 113: Loss = 0.0141
# Epoch 114: Loss = 0.0141
# Epoch 115: Loss = 0.0139
# Epoch 116: Loss = 0.0138
# Epoch 117: Loss = 0.0138
# Epoch 118: Loss = 0.0138
# Epoch 119: Loss = 0.0134
# Epoch 120: Loss = 0.0140
# Epoch 121: Loss = 0.0176
# Epoch 122: Loss = 0.0145
# Epoch 123: Loss = 0.0144
# Epoch 124: Loss = 0.0139
# Epoch 125: Loss = 0.0135
# Epoch 126: Loss = 0.0133
# Epoch 127: Loss = 0.0131
# Epoch 128: Loss = 0.0131
# Epoch 129: Loss = 0.0128
# Epoch 130: Loss = 0.0130
# Epoch 131: Loss = 0.0127
# Epoch 132: Loss = 0.0128
# Epoch 133: Loss = 0.0127
# Epoch 134: Loss = 0.0127
# Epoch 135: Loss = 0.0128
# Epoch 136: Loss = 0.0127
# Epoch 137: Loss = 0.0127
# Epoch 138: Loss = 0.0124
# Epoch 139: Loss = 0.0122
# Epoch 140: Loss = 0.0120
# Epoch 141: Loss = 0.0120
# Epoch 142: Loss = 0.0129
# Epoch 143: Loss = 0.0131
# Epoch 144: Loss = 0.0123
# Epoch 145: Loss = 0.0127
# Epoch 146: Loss = 0.0118
# Epoch 147: Loss = 0.0119
# Epoch 148: Loss = 0.0127
# Epoch 149: Loss = 0.0117
# Epoch 150: Loss = 0.0116
# Epoch 151: Loss = 0.0114
# Epoch 152: Loss = 0.0115
# Epoch 153: Loss = 0.0114
# Epoch 154: Loss = 0.0113
# Epoch 155: Loss = 0.0110
# Epoch 156: Loss = 0.0110
# Epoch 157: Loss = 0.0111
# Epoch 158: Loss = 0.0110
# Epoch 159: Loss = 0.0109
# Epoch 160: Loss = 0.0125
# Epoch 161: Loss = 0.0130
# Epoch 162: Loss = 0.0121
# Epoch 163: Loss = 0.0115
# Epoch 164: Loss = 0.0111
# Epoch 165: Loss = 0.0110
# Epoch 166: Loss = 0.0116
# Epoch 167: Loss = 0.0108
# Epoch 168: Loss = 0.0109
# Epoch 169: Loss = 0.0107
# Epoch 170: Loss = 0.0105
# Epoch 171: Loss = 0.0104
# Epoch 172: Loss = 0.0105
# Epoch 173: Loss = 0.0180
# Epoch 257: Loss = 0.0086
# Epoch 258: Loss = 0.0163
# Epoch 259: Loss = 0.0157
# Epoch 260: Loss = 0.0131
# Epoch 261: Loss = 0.0122
# Epoch 262: Loss = 0.0103
# Epoch 263: Loss = 0.0103
# Epoch 264: Loss = 0.0097
# Epoch 265: Loss = 0.0097
# Epoch 266: Loss = 0.0105
# Epoch 267: Loss = 0.0093
# Epoch 268: Loss = 0.0093
# Epoch 269: Loss = 0.0091
# Epoch 270: Loss = 0.0089
# Epoch 271: Loss = 0.0090
# Epoch 272: Loss = 0.0092
# Epoch 273: Loss = 0.0092
# Epoch 274: Loss = 0.0091
# Epoch 275: Loss = 0.0087
# Epoch 276: Loss = 0.0102
# Epoch 277: Loss = 0.0088
# Epoch 278: Loss = 0.0089
# Epoch 279: Loss = 0.0103
# Epoch 280: Loss = 0.0093
# Epoch 281: Loss = 0.0099
# Epoch 282: Loss = 0.0093
# Epoch 283: Loss = 0.0088
# Epoch 284: Loss = 0.0086
# Epoch 285: Loss = 0.0087
# Epoch 286: Loss = 0.0086
# Epoch 287: Loss = 0.0085
# Epoch 288: Loss = 0.0084
# Epoch 289: Loss = 0.0086
# Epoch 290: Loss = 0.0084
# Epoch 291: Loss = 0.0085
# Epoch 292: Loss = 0.0083
# Epoch 293: Loss = 0.0084
# Epoch 294: Loss = 0.0097
# Epoch 295: Loss = 0.0098
# Epoch 296: Loss = 0.0090
# Epoch 297: Loss = 0.0087
# Epoch 298: Loss = 0.0085
# Epoch 299: Loss = 0.0083
# Epoch 300: Loss = 0.0082
# Epoch 301: Loss = 0.0082
# Epoch 302: Loss = 0.0083
# Epoch 303: Loss = 0.0082
# Epoch 304: Loss = 0.0079
# Epoch 305: Loss = 0.0079
# Epoch 306: Loss = 0.0080
# Epoch 307: Loss = 0.0081
# Epoch 308: Loss = 0.0078
# Epoch 309: Loss = 0.0081
# Epoch 310: Loss = 0.0083
# Epoch 311: Loss = 0.0100
# Epoch 312: Loss = 0.0085
# Epoch 313: Loss = 0.0082
# Epoch 314: Loss = 0.0095
# Epoch 315: Loss = 0.0081
# Epoch 316: Loss = 0.0094
# Epoch 317: Loss = 0.0082
# Epoch 318: Loss = 0.0079
# Epoch 319: Loss = 0.0080
# Epoch 320: Loss = 0.0077
# Epoch 321: Loss = 0.0079
# Epoch 322: Loss = 0.0080
# Epoch 323: Loss = 0.0077
# Epoch 324: Loss = 0.0082
# Epoch 325: Loss = 0.0079
# Epoch 326: Loss = 0.0076
# Epoch 327: Loss = 0.0080
# Epoch 328: Loss = 0.0075
# Epoch 329: Loss = 0.0093
# Epoch 330: Loss = 0.0086
# Epoch 331: Loss = 0.0080
# Epoch 332: Loss = 0.0077
# Epoch 333: Loss = 0.0076
# Epoch 334: Loss = 0.0078
# Epoch 335: Loss = 0.0075
# Epoch 336: Loss = 0.0076
# Epoch 337: Loss = 0.0073
# Epoch 338: Loss = 0.0074
# Epoch 339: Loss = 0.0073
# Epoch 340: Loss = 0.0074
# Epoch 424: Loss = 0.0153
# Epoch 425: Loss = 0.0133
# Epoch 426: Loss = 0.0125
# Epoch 427: Loss = 0.0118
# Epoch 428: Loss = 0.0115
# Epoch 429: Loss = 0.0117
# Epoch 430: Loss = 0.0113
# Epoch 431: Loss = 0.0107
# Epoch 432: Loss = 0.0102
# Epoch 433: Loss = 0.0098
# Epoch 434: Loss = 0.0097
# Epoch 435: Loss = 0.0096
# Epoch 436: Loss = 0.0094
# Epoch 437: Loss = 0.0092
# Epoch 438: Loss = 0.0089
# Epoch 439: Loss = 0.0092
# Epoch 440: Loss = 0.0088
# Epoch 441: Loss = 0.0148
# Epoch 442: Loss = 0.0126
# Epoch 443: Loss = 0.0127
# Epoch 444: Loss = 0.0113
# Epoch 445: Loss = 0.0104
# Epoch 446: Loss = 0.0099
# Epoch 447: Loss = 0.0097
# Epoch 448: Loss = 0.0093
# Epoch 449: Loss = 0.0091
# Epoch 450: Loss = 0.0091
# Epoch 451: Loss = 0.0088
# Epoch 452: Loss = 0.0086
# Epoch 453: Loss = 0.0084
# Epoch 454: Loss = 0.0085
# Epoch 455: Loss = 0.0089
# Epoch 456: Loss = 0.0083
# Epoch 457: Loss = 0.0101
# Epoch 458: Loss = 0.0085
# Epoch 459: Loss = 0.0081
# Epoch 460: Loss = 0.0082
# Epoch 461: Loss = 0.0081
# Epoch 462: Loss = 0.0079
# Epoch 463: Loss = 0.0078
# Epoch 464: Loss = 0.0080
# Epoch 465: Loss = 0.0076
# Epoch 466: Loss = 0.0078
# Epoch 467: Loss = 0.0076
# Epoch 468: Loss = 0.0078
# Epoch 469: Loss = 0.0075
# Epoch 470: Loss = 0.0076
# Epoch 471: Loss = 0.0075
# Epoch 472: Loss = 0.0074
# Epoch 473: Loss = 0.0074
# Epoch 474: Loss = 0.0073
# Epoch 475: Loss = 0.0073
# Epoch 476: Loss = 0.0071
# Epoch 477: Loss = 0.0072
# Epoch 478: Loss = 0.0071
# Epoch 479: Loss = 0.0074
# Epoch 480: Loss = 0.0088
# Epoch 481: Loss = 0.0080
# Epoch 482: Loss = 0.0086
# Epoch 483: Loss = 0.0076
# Epoch 484: Loss = 0.0075
# Epoch 485: Loss = 0.0071
# Epoch 486: Loss = 0.0070
# Epoch 487: Loss = 0.0070
# Epoch 488: Loss = 0.0071
# Epoch 489: Loss = 0.0070
# Epoch 490: Loss = 0.0068
# Epoch 491: Loss = 0.0069
# Epoch 492: Loss = 0.0067
# Epoch 493: Loss = 0.0069
# Epoch 494: Loss = 0.0071
# Epoch 495: Loss = 0.0073
# Epoch 496: Loss = 0.0068
# Epoch 497: Loss = 0.0069
# Epoch 498: Loss = 0.0069
# Epoch 499: Loss = 0.0066

# %%
plt.plot(history_loss[:, 0], history_loss[:, 1])
plt.yscale('log')
plt.show()

# %%
data_dir = "/csim2/zhangzhiyu/MyProjects/DiffDispHighMode/Dispersion/dataset_png/train"
dataset = MaskDataset(data_dir)
loader = DataLoader(dataset, batch_size=16, shuffle=True)

# 可视化最后一个 batch 的第一个样本
x, y_masks, y_types = next(iter(loader))

i = 2
model.eval()
with torch.no_grad():
    pred_masks, pred_types = model(x.cuda())
fig, ax = plt.subplots(1, 1, figsize=(8, 4))

matrix = x[i]
pred_mask = pred_masks[i]
pred_type = pred_types[i]
threshold = 0.05

ax.imshow(matrix.squeeze().cpu(), cmap='gray', aspect='auto')
pred_mask = torch.sigmoid(pred_mask)
pred_type = pred_type.argmax(dim=1)

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

legend_elements = []
styles = ['x', '+', 'x', '+', 'x', '+']
for i in range(pred_mask.shape[0]):
    mask = pred_mask[i] > threshold
    if mask.sum() > 0:
        coords = torch.nonzero(mask, as_tuple=False).cpu().numpy()
        if coords.size > 0:
            ax.plot(coords[:, 1], coords[:, 0],
                    styles[pred_type[i]],
                    color=f"C{i}",
                    label=f"type{pred_type[i]}")
            legend_elements.append(Line2D([0], [0], color=f"C{i}", marker=styles[pred_type[i]], linestyle='None', label=f"type{pred_type[i]}"))

ax.set_title("Predicted Masks")
ax.legend(handles=legend_elements)
fig.tight_layout()
plt.show()

# %%
# data_dir = "/csim2/zhangzhiyu/MyProjects/DiffDispHighMode/Dispersion/dataset_png/test"
data_dir = "/csim2/zhangzhiyu/MyProjects/DiffDispHighMode/Dispersion/dataset_png/train"
dataset = MaskDataset(data_dir, max_lines=5)
loader = DataLoader(dataset, batch_size=16, shuffle=True)

# 可视化最后一个 batch 的第一个样本
x, y_masks, y_types = next(iter(loader))

j = 2
model.eval()
with torch.no_grad():
    pred_masks, pred_types = model(x.cuda())
fig, ax = plt.subplots(1, 1, figsize=(8, 4))

matrix = x[j]
y_type = y_types[j]
pred_mask = pred_masks[j]
pred_type = pred_types[j]
threshold = 0.15

ax.imshow(matrix.squeeze().cpu(), cmap='gray', aspect='auto')
pred_mask = torch.sigmoid(pred_mask)
pred_type = pred_type.argmax(dim=1)

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

legend_elements = []

styles = ['x', '+', 'x', '+', 'x', '+']
for i in range(pred_mask.shape[0]):
    mask = pred_mask[i] > threshold
    if mask.sum() > 0:
        coords = torch.nonzero(mask, as_tuple=False).cpu().numpy()
        if coords.size > 0:
            ax.plot(coords[:, 1], coords[:, 0], 
                    styles[pred_type[i]], 
                    color=f"C{i}", 
                    label=f"type{pred_type[i]}")
            legend_elements.append(Line2D([0], [0], color=f"C{i}", marker=styles[pred_type[i]], linestyle='None', label=f"type{pred_type[i]}"))

ax.set_title("Predicted Masks")
ax.legend(handles=legend_elements)
fig.tight_layout()
plt.show()

# %%
pred_type[i]
# Out:
# tensor(0, device='cuda:0')

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 6))
axes[0].imshow(pred_masks[i][0].squeeze().cpu(), cmap='jet', aspect='auto')
axes[1].imshow(pred_masks[i][1].squeeze().cpu(), cmap='jet', aspect='auto')
axes[2].imshow(pred_masks[i][2].squeeze().cpu(), cmap='jet', aspect='auto')

# %%
y_masks[i][0].shape
# Out:
# torch.Size([512, 128])

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 6))
axes[0].imshow(y_masks[i][0].squeeze().cpu(), cmap='jet', aspect='auto')
axes[1].imshow(y_masks[i][1].squeeze().cpu(), cmap='jet', aspect='auto')
axes[2].imshow(y_masks[i][2].squeeze().cpu(), cmap='jet', aspect='auto')
