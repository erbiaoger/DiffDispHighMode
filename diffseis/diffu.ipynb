# %%
from diffseis.diffusion import GaussianDiffusion, Trainer, Dataset
from diffseis.unet import UNet

# %%
mode = "denoising" #demultiple, interpolation, denoising
folder = "/home/lty/MyProjects/Seismology/diffseis/dataset/"+mode+"/data_train/"
image_size = (256,256)

ds  = Dataset(folder, image_size, mode)               # 数据集

# %%
X, y = next(iter(ds))
X.shape, y.shape

# %%
import matplotlib.pyplot as plt

plt.imshow(X[3], cmap="gray")

# %%
import numpy as np
from PIL import Image

filename = '/home/lty/MyProjects/Seismology/diffseis/dataset/demultiple/data_train/data/001.png'
# filename = '/home/lty/MyProjects/Seismology/diffseis/dataset/demultiple/data_train/labels/001.png'
# filename = '/home/lty/MyProjects/diffseis/dataset/demultiple/data_train/data/2024-01-31-20-09-35-out.png'

data = Image.open(filename)
data = np.array(data)
data.shape
# Out:
# (1440, 1920)

# %%
image_numpy = data

image_pil = Image.fromarray(image_numpy)
h, w, _ = image_numpy.shape

image_pil.save('test.png')

# %%
data = Image.open('test.png')
data = np.array(data)
data.shape
# Out:
# (1500, 1980, 4)

# %%
plt.imshow(data, cmap="gray")

# %%
def save_image(image_numpy, image_path, aspect_ratio=1.0):
    """Save a numpy image to the disk

    Parameters:
        image_numpy (numpy array) -- input numpy array
        image_path (str)          -- the path of the image
    """

    image_pil = Image.fromarray(image_numpy)
    h, w, _ = image_numpy.shape

    if aspect_ratio is None:
        pass
    elif aspect_ratio > 1.0:
        image_pil = image_pil.resize((h, int(w * aspect_ratio)), Image.BICUBIC)
    elif aspect_ratio < 1.0:
        image_pil = image_pil.resize((int(h / aspect_ratio), w), Image.BICUBIC)
    image_pil.save(image_path)

# %%
data

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 生成数据
X = np.linspace(1, 100, 100)
Y = np.linspace(1, 100, 100)
X, Y = np.meshgrid(X, Y)
Z = 1/X**2 + 1/Y**2

# 创建3D图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制图像
ax.plot_wireframe(X, Y, Z)

# 设置标签
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# 显示图像
plt.show()
